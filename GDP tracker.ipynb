# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %%
dados = pd.read_csv("C://Users//User//Desktop//Projetos Programação//Global Economy Indicators.csv")
dados = dados.dropna()

# %%
#x = dados.drop([' Gross Domestic Product (GDP) '], axis = 1)
#x = x.drop([' Currency '], axis = 1)
#x = x.drop([' Country '], axis = 1)
#x = x.drop([' CountryID '], axis = 1)
#x = x.drop([' Year '], axis = 1)
#x = x.drop([' Per capita GNI '], axis = 1)
#x = x.drop([' Gross National Income(GNI) in USD '], axis = 1)
#x = x.drop([' Total Value Added '], axis = 1)
#x = x.drop([' AMA exchange rate '], axis = 1)
#x = x.drop([' IMF based exchange rate '], axis = 1)
#x = x.drop([' Imports of goods and services '], axis = 1)


y = dados[' Gross Domestic Product (GDP) ']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)


print(f'Mean Squared Error: {mse}')
print(f'R² Score: {r2}')
print("Coefficients:")
for feature, coef in zip(x.columns, model.coef_):
    print(f"{feature}: {coef:.4f}")

print(f"\nIntercept: {model.intercept_:.4f}")
# Out:
# Mean Squared Error: 1.660030315581076e+20
# R² Score: 0.9998393849410235
# Coefficients:
#  Population : -12.1615
#  Agriculture, hunting, forestry, fishing (ISIC A-B) : 0.6164
#  Changes in inventories : 1.7689
#  Construction (ISIC F) : 1.0181
#  Exports of goods and services : 0.1465
#  Final consumption expenditure : 0.8702
#  General government final consumption expenditure : -0.0777
#  Gross capital formation : -1.3272
#  Gross fixed capital formation (including Acquisitions less disposals of valuables) : 1.6160
#  Household consumption expenditure (including Non-profit institutions serving households) : -0.3129
#  Manufacturing (ISIC D) : 0.1099
#  Mining, Manufacturing, Utilities (ISIC C-E) : 0.4770
#  Other Activities (ISIC J-P) : 0.3607
#  Transport, storage and communication (ISIC I) : 0.6505
#  Wholesale, retail trade, restaurants and hotels (ISIC G-H) : 0.2169
#
# Intercept: -860869876.9160

# %%
equation = f"y = {model.intercept_:.4f}"

# Add each feature with its coefficient
for feature_name, coefficient in zip(x.columns, model.coef_):
    if coefficient >= 0:
        equation += f" + {coefficient:.2f}{feature_name[1:3]}"
    else:
        equation += f" - {abs(coefficient):.2f}{feature_name[1:3]}"

# Print the equation
print("Linear Regression Equation:")
print(equation)
# Out:
# Linear Regression Equation:
# y = -860869876.9160 - 12.16Po + 0.62Ag + 1.77Ch + 1.02Co + 0.15Ex + 0.87Fi - 0.08Ge - 1.33Gr + 1.62Gr - 0.31Ho + 0.11Ma + 0.48Mi + 0.36Ot + 0.65Tr + 0.22Wh
